# %%
import timeit

# %%
import pandas as pd
import sqlalchemy as db
engine = db.create_engine('sqlite:///../data/RawHealthData.db')

# %%
sql = """
SELECT * FROM ihme_gbd_2017_data_cb71683c_10
UNION
SELECT * FROM ihme_gbd_2017_data_cb71683c_11
UNION
SELECT * FROM ihme_gbd_2017_data_cb71683c_12;
"""
start = timeit.default_timer()
df = pd.read_sql_query(sql, engine)
stop = timeit.default_timer()

# %%
metadata.loc[(metadata['type'] == 'table')]
# Out:
#       type                                               name  \
# 0    table                     ihme_gbd_2017_data_cb71683c_10
# 2    table                     ihme_gbd_2017_data_cb71683c_11
# 4    table                     ihme_gbd_2017_data_cb71683c_12
# 6    table                     ihme_gbd_2017_data_cb71683c_14
# 8    table                     ihme_gbd_2017_data_cb71683c_15
# 10   table                     ihme_gbd_2017_data_cb71683c_17
# 12   table                     ihme_gbd_2017_data_cb71683c_18
# 14   table                     ihme_gbd_2017_data_cb71683c_19
# 16   table                      ihme_gbd_2017_data_cb71683c_2
# 18   table                     ihme_gbd_2017_data_cb71683c_20
# 20   table                     ihme_gbd_2017_data_cb71683c_21
# 22   table                     ihme_gbd_2017_data_cb71683c_22
# 24   table                     ihme_gbd_2017_data_cb71683c_23
# 26   table                     ihme_gbd_2017_data_cb71683c_24
# 28   table                     ihme_gbd_2017_data_cb71683c_25
# 30   table                     ihme_gbd_2017_data_cb71683c_26
# 32   table             number_of_deaths_from_secondhand_smoke
# 34   table              number_of_deaths_from_tobacco_smoking
# 36   table                      number_of_total_daily_smokers
# 38   table              sales_of_cigarettes_per_adult_per_day
# 40   table                     secondhand_smoke_deaths_by_age
# 42   table  share_of_adults_who_are_smoking_by_level_of_pr...
# 44   table                          share_of_adults_who_smoke
# 46   table       share_of_cancer_deaths_attributed_to_tobacco
# 48   table          share_of_tobacco_retail_price_that_is_tax
# 50   table                                             metric
# 52   table                      smoking_and_secondhand_deaths
# 54   table                              smoking_deaths_by_age
# 56   table                support_to_help_to_quit_tobacco_use
# 58   table                  taxes_as_share_of_cigarette_price
# 60   table                                  wdicountry_series
# 62   table                                         wdicountry
# 64   table                                        wdifootnote
# 66   table                     ihme_gbd_2017_data_cb71683c_27
# 68   table                     ihme_gbd_2017_data_cb71683c_28
# 70   table                     ihme_gbd_2017_data_cb71683c_29
# 72   table                      ihme_gbd_2017_data_cb71683c_3
# 74   table                     ihme_gbd_2017_data_cb71683c_30
# 76   table                     ihme_gbd_2017_data_cb71683c_31
# 78   table                      ihme_gbd_2017_data_cb71683c_4
# 80   table                      ihme_gbd_2017_data_cb71683c_5
# 82   table                      ihme_gbd_2017_data_cb71683c_6
# 84   table                      ihme_gbd_2017_data_cb71683c_7
# 86   table                      ihme_gbd_2017_data_cb71683c_8
# 88   table                      ihme_gbd_2017_data_cb71683c_9
# 90   table                      ihme_gbd_2017_data_cb71683c_1
# 92   table              average_price_of_a_pack_of_cigarettes
# 94   table  comparing_the_share_of_men_and_women_who_are_s...
# 96   table              consumption_per_smoker_per_day_bounds
# 98   table                     consumption_per_smoker_per_day
# 100  table                                      country_codes
# 102  table                    daily_smoking_prevalence_bounds
# 104  table         enforcement_of_bans_on_tobacco_advertising
# 106  table                                            measure
# 108  table                                           location
# 110  table                                                sex
# 112  table                                                age
# 114  table                                              cause
# 116  table                          wdi_descriptions_footnote
#
#                                               tbl_name  rootpage  \
# 0                       ihme_gbd_2017_data_cb71683c_10         2
# 2                       ihme_gbd_2017_data_cb71683c_11      7930
# 4                       ihme_gbd_2017_data_cb71683c_12     15834
# 6                       ihme_gbd_2017_data_cb71683c_14     23817
# 8                       ihme_gbd_2017_data_cb71683c_15     31753
# 10                      ihme_gbd_2017_data_cb71683c_17     39719
# 12                      ihme_gbd_2017_data_cb71683c_18     47678
# 14                      ihme_gbd_2017_data_cb71683c_19     55599
# 16                       ihme_gbd_2017_data_cb71683c_2     63541
# 18                      ihme_gbd_2017_data_cb71683c_20     71758
# 20                      ihme_gbd_2017_data_cb71683c_21     79718
# 22                      ihme_gbd_2017_data_cb71683c_22     87647
# 24                      ihme_gbd_2017_data_cb71683c_23     95646
# 26                      ihme_gbd_2017_data_cb71683c_24    103667
# 28                      ihme_gbd_2017_data_cb71683c_25    111696
# 30                      ihme_gbd_2017_data_cb71683c_26    119654
# 32              number_of_deaths_from_secondhand_smoke    127537
# 34               number_of_deaths_from_tobacco_smoking    127556
# 36                       number_of_total_daily_smokers    127574
# 38               sales_of_cigarettes_per_adult_per_day    127638
# 40                      secondhand_smoke_deaths_by_age    127671
# 42   share_of_adults_who_are_smoking_by_level_of_pr...    127805
# 44                           share_of_adults_who_smoke    128314
# 46        share_of_cancer_deaths_attributed_to_tobacco    128336
# 48           share_of_tobacco_retail_price_that_is_tax    128355
# 50                                              metric    128366
# 52                       smoking_and_secondhand_deaths    136250
# 54                               smoking_deaths_by_age    136341
# 56                 support_to_help_to_quit_tobacco_use    136447
# 58                   taxes_as_share_of_cigarette_price    136457
# 60                                   wdicountry_series    136461
# 62                                          wdicountry    136683
# 64                                         wdifootnote    136716
# 66                      ihme_gbd_2017_data_cb71683c_27    153265
# 68                      ihme_gbd_2017_data_cb71683c_28    161176
# 70                      ihme_gbd_2017_data_cb71683c_29    169089
# 72                       ihme_gbd_2017_data_cb71683c_3    177023
# 74                      ihme_gbd_2017_data_cb71683c_30    184935
# 76                      ihme_gbd_2017_data_cb71683c_31    192815
# 78                       ihme_gbd_2017_data_cb71683c_4    199546
# 80                       ihme_gbd_2017_data_cb71683c_5    207491
# 82                       ihme_gbd_2017_data_cb71683c_6    215414
# 84                       ihme_gbd_2017_data_cb71683c_7    223376
# 86                       ihme_gbd_2017_data_cb71683c_8    231339
# 88                       ihme_gbd_2017_data_cb71683c_9    239296
# 90                       ihme_gbd_2017_data_cb71683c_1    247193
# 92               average_price_of_a_pack_of_cigarettes    255659
# 94   comparing_the_share_of_men_and_women_who_are_s...    255664
# 96               consumption_per_smoker_per_day_bounds    256149
# 98                      consumption_per_smoker_per_day    256245
# 100                                      country_codes    256316
# 102                    daily_smoking_prevalence_bounds    256325
# 104         enforcement_of_bans_on_tobacco_advertising    256421
# 106                                            measure    256431
# 108                                           location    256433
# 110                                                sex    256441
# 112                                                age    256444
# 114                                              cause    256446
# 116                          wdi_descriptions_footnote    256452
#
#                                                    sql
# 0    CREATE TABLE ihme_gbd_2017_data_cb71683c_10 (\...
# 2    CREATE TABLE ihme_gbd_2017_data_cb71683c_11 (\...
# 4    CREATE TABLE ihme_gbd_2017_data_cb71683c_12 (\...
# 6    CREATE TABLE ihme_gbd_2017_data_cb71683c_14 (\...
# 8    CREATE TABLE ihme_gbd_2017_data_cb71683c_15 (\...
# 10   CREATE TABLE ihme_gbd_2017_data_cb71683c_17 (\...
# 12   CREATE TABLE ihme_gbd_2017_data_cb71683c_18 (\...
# 14   CREATE TABLE ihme_gbd_2017_data_cb71683c_19 (\...
# 16   CREATE TABLE ihme_gbd_2017_data_cb71683c_2 (\n...
# 18   CREATE TABLE ihme_gbd_2017_data_cb71683c_20 (\...
# 20   CREATE TABLE ihme_gbd_2017_data_cb71683c_21 (\...
# 22   CREATE TABLE ihme_gbd_2017_data_cb71683c_22 (\...
# 24   CREATE TABLE ihme_gbd_2017_data_cb71683c_23 (\...
# 26   CREATE TABLE ihme_gbd_2017_data_cb71683c_24 (\...
# 28   CREATE TABLE ihme_gbd_2017_data_cb71683c_25 (\...
# 30   CREATE TABLE ihme_gbd_2017_data_cb71683c_26 (\...
# 32   CREATE TABLE number_of_deaths_from_secondhand_...
# 34   CREATE TABLE number_of_deaths_from_tobacco_smo...
# 36   CREATE TABLE number_of_total_daily_smokers (\n...
# 38   CREATE TABLE sales_of_cigarettes_per_adult_per...
# 40   CREATE TABLE secondhand_smoke_deaths_by_age (\...
# 42   CREATE TABLE share_of_adults_who_are_smoking_b...
# 44   CREATE TABLE share_of_adults_who_smoke (\n\t"i...
# 46   CREATE TABLE share_of_cancer_deaths_attributed...
# 48   CREATE TABLE share_of_tobacco_retail_price_tha...
# 50   CREATE TABLE metric (\n\t"index" BIGINT, \n\t"...
# 52   CREATE TABLE smoking_and_secondhand_deaths (\n...
# 54   CREATE TABLE smoking_deaths_by_age (\n\t"index...
# 56   CREATE TABLE support_to_help_to_quit_tobacco_u...
# 58   CREATE TABLE taxes_as_share_of_cigarette_price...
# 60   CREATE TABLE wdicountry_series (\n\t"index" BI...
# 62   CREATE TABLE wdicountry (\n\t"index" BIGINT, \...
# 64   CREATE TABLE wdifootnote (\n\t"index" BIGINT, ...
# 66   CREATE TABLE ihme_gbd_2017_data_cb71683c_27 (\...
# 68   CREATE TABLE ihme_gbd_2017_data_cb71683c_28 (\...
# 70   CREATE TABLE ihme_gbd_2017_data_cb71683c_29 (\...
# 72   CREATE TABLE ihme_gbd_2017_data_cb71683c_3 (\n...
# 74   CREATE TABLE ihme_gbd_2017_data_cb71683c_30 (\...
# 76   CREATE TABLE ihme_gbd_2017_data_cb71683c_31 (\...
# 78   CREATE TABLE ihme_gbd_2017_data_cb71683c_4 (\n...
# 80   CREATE TABLE ihme_gbd_2017_data_cb71683c_5 (\n...
# 82   CREATE TABLE ihme_gbd_2017_data_cb71683c_6 (\n...
# 84   CREATE TABLE ihme_gbd_2017_data_cb71683c_7 (\n...
# 86   CREATE TABLE ihme_gbd_2017_data_cb71683c_8 (\n...
# 88   CREATE TABLE ihme_gbd_2017_data_cb71683c_9 (\n...
# 90   CREATE TABLE ihme_gbd_2017_data_cb71683c_1 (\n...
# 92   CREATE TABLE average_price_of_a_pack_of_cigare...
# 94   CREATE TABLE comparing_the_share_of_men_and_wo...
# 96   CREATE TABLE consumption_per_smoker_per_day_bo...
# 98   CREATE TABLE consumption_per_smoker_per_day (\...
# 100  CREATE TABLE country_codes (\n\t"index" BIGINT...
# 102  CREATE TABLE daily_smoking_prevalence_bounds (...
# 104  CREATE TABLE enforcement_of_bans_on_tobacco_ad...
# 106  CREATE TABLE measure (\n\tlevel_0 BIGINT, \n\t...
# 108  CREATE TABLE location (\n\tlevel_0 BIGINT, \n\...
# 110  CREATE TABLE sex (\n\tlevel_0 BIGINT, \n\t"ind...
# 112  CREATE TABLE age (\n\tlevel_0 BIGINT, \n\t"ind...
# 114  CREATE TABLE cause (\n\tlevel_0 BIGINT, \n\t"i...
# 116  CREATE TABLE wdi_descriptions_footnote (\n\t"i...
